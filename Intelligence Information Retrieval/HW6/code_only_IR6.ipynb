# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# go to IIR_CA^ directory
# %cd /content/drive/My Drive/Colab Notebooks/Master_course_Homeworks/Intelligence Information Retrieval/HW6/
# Out:
# /content/drive/My Drive/Colab Notebooks/Master_course_Homeworks/Intelligence Information Retrieval/HW6

# %%
# !pip install nbformat
import nbformat
nb = nbformat.read('IIR_CA6.ipynb', as_version=4)
if 'widgets' in nb.metadata:
    del nb.metadata['widgets']
nbformat.write(nb, 'IIR_CA6_visible_for_github.ipynb')
print('Done!')
# Out:
# ...
# Done!
